# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('http://taanila.fi/employee.csv')

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
Education = ['level 1', 'level 2', 'level 3', 'level 4']

# %%
df[['Age', 'YearsAtCompany']].describe().style.format('{:.1f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_de01df06_7b28_11e9_9eba_ccaf78e78747" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Age</th>
#         <th class="col_heading level0 col1" >YearsAtCompany</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_de01df06_7b28_11e9_9eba_ccaf78e78747level0_row0" class="row_heading level0 row0" >count</th>
#         <td id="T_de01df06_7b28_11e9_9eba_ccaf78e78747row0_col0" class="data row0 col0" >1470.0</td>
#         <td id="T_de01df06_7b28_11e9_9eba_ccaf78e78747row0_col1" class="data row0 col1" >1470.0</td>
#     </tr>    <tr>
#         <th id="T_de01df06_7b28_11e9_9eba_ccaf78e78747level0_row1" class="row_heading level0 row1" >mean</th>
#         <td id="T_de01df06_7b28_11e9_9eba_ccaf78e78747row1_col0" class="data row1 col0" >36.9</td>
#         <td id="T_de01df06_7b28_11e9_9eba_ccaf78e78747row1_col1" class="data row1 col1" >7.0</td>
#     </tr>    <tr>
# ...

# %%
#Ruutu- ja janakaavio on kätevä jakaumien vertailussa
ax = df.boxplot('Age', by = 'Education')
plt.title('')
plt.suptitle('')
plt.xlabel('Education')
plt.ylabel('Age')
ax.set_xticklabels(Education)
# Out:
# [Text(0, 0, 'level 1'),
#  Text(0, 0, 'level 2'),
#  Text(0, 0, 'level 3'),
#  Text(0, 0, 'level 4')]

# %%
df[['Age','Education','DailyRate']].corr().style.format('{:.2f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Age</th>
#         <th class="col_heading level0 col1" >Education</th>
#         <th class="col_heading level0 col2" >DailyRate</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747level0_row0" class="row_heading level0 row0" >Age</th>
#         <td id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747row0_col0" class="data row0 col0" >1.00</td>
#         <td id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747row0_col1" class="data row0 col1" >0.21</td>
#         <td id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747row0_col2" class="data row0 col2" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f60e2200_7b2b_11e9_be38_ccaf78e78747level0_row1" class="row_heading level0 row1" >Education</th>
# ...

# %%
df.plot.scatter('StockOptionLevel','YearsAtCompany')

# %%
df.plot.scatter('Age','YearsAtCompany')

# %%
df.plot.scatter('Age','DailyRate')

# %%
df.plot.scatter('DailyRate','YearsAtCompany')
