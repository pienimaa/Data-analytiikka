# %%
import pandas as pd

# %%
df=pd.read_excel('http://taanila.fi/kunnat.xlsx')
df.head()
# Out:
#        Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0       Akaa                   88.5           16769
# 1   Alajärvi                   60.7            9831
# 2  Alavieska                   52.6            2610
# 3     Alavus                   59.5           11713
# 4   Asikkala                   64.4            8248
#
#    Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 0                                            -0.9
# 1                                            -0.7
# 2                                            -1.1
# 3                                            -1.6
# 4                                            -0.9
#
#    Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 0                                         18.0
# 1                                         17.7
# 2                                         19.6
# 3                                         17.0
# 4                                         14.2
#
#    15-64 -vuotiaiden osuus väestöstä, %, 2017  \
# ...

# %%
df.tail()
# Out:
#          Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 306  Ylivieska                   86.0           15251
# 307   Ylöjärvi                   88.2           32878
# 308      Ypäjä                   40.8            2372
# 309     Ähtäri                   62.2            5906
# 310  Äänekoski                   75.4           19144
#
#      Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 306                                             0.3
# 307                                             0.2
# 308                                            -0.4
# 309                                            -1.3
# 310                                            -1.2
#
#      Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 306                                         21.5
# 307                                         21.8
# 308                                         13.4
# 309                                         14.6
# 310                                         16.4
#
# ...

# %%
df.shape
# Out:
# (311, 32)

# %%
df.columns
# Out:
# Index(['Kunta', 'Taajama-aste, %, 2017', 'Väkiluku, 2017',
#        'Väkiluvun muutos edellisestä vuodesta, %, 2017',
#        'Alle 15-vuotiaiden osuus väestöstä, %, 2017',
#        '15-64 -vuotiaiden osuus väestöstä, %, 2017',
#        'Yli 64-vuotiaiden osuus väestöstä, %, 2017',
#        'Ruotsinkielisten osuus väestöstä, %, 2017',
#        'Ulkomaan kansalaisten osuus väestöstä, %, 2017',
#        'Syntyneiden enemmyys, henkilöä, 2017',
#        'Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017',
#        'Perheiden lukumäärä, 2017', 'Asuntokuntien lukumäärä, 2017',
#        'Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017',
#        'Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017',
#        'Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Alueella asuvan työllisen työvoiman määrä, 2016',
# ...

# %%
df.rename(columns = {'Vuosikate, euroa/asukas, 2017': 'Vuosikate, 2017'}, inplace = True)
df.tail()
# Out:
#          Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 306  Ylivieska                   86.0           15251
# 307   Ylöjärvi                   88.2           32878
# 308      Ypäjä                   40.8            2372
# 309     Ähtäri                   62.2            5906
# 310  Äänekoski                   75.4           19144
#
#      Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 306                                             0.3
# 307                                             0.2
# 308                                            -0.4
# 309                                            -1.3
# 310                                            -1.2
#
#      Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 306                                         21.5
# 307                                         21.8
# 308                                         13.4
# 309                                         14.6
# 310                                         16.4
#
# ...

# %%
df.rename(columns = {'Vuosikate, 2017':'Vuosikate, euroa/asukas, 2017' }, inplace = True)
df.head()
# Out:
#        Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0       Akaa                   88.5           16769
# 1   Alajärvi                   60.7            9831
# 2  Alavieska                   52.6            2610
# 3     Alavus                   59.5           11713
# 4   Asikkala                   64.4            8248
#
#    Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 0                                            -0.9
# 1                                            -0.7
# 2                                            -1.1
# 3                                            -1.6
# 4                                            -0.9
#
#    Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 0                                         18.0
# 1                                         17.7
# 2                                         19.6
# 3                                         17.0
# 4                                         14.2
#
#    15-64 -vuotiaiden osuus väestöstä, %, 2017  \
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of              Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0             Akaa                   88.5           16769
# 1         Alajärvi                   60.7            9831
# 2        Alavieska                   52.6            2610
# 3           Alavus                   59.5           11713
# 4         Asikkala                   64.4            8248
# 5           Askola                   53.2            4990
# 6             Aura                   69.9            3991
# 7           Brändö                    0.0             452
# 8           Eckerö                   41.8             948
# 9        Enonkoski                   39.9            1416
# 10       Enontekiö                   30.7            1893
# 11           Espoo                   99.5          279044
# 12            Eura                   72.3           11910
# 13        Eurajoki                   62.9            9521
# 14        Evijärvi                   35.7            2499
# ...

# %%
for var in df:
    print(var, pd.unique(df[var]))
# Out:
# Kunta ['Akaa' 'Alajärvi' 'Alavieska' 'Alavus' 'Asikkala' 'Askola' 'Aura'
#  'Brändö' 'Eckerö' 'Enonkoski' 'Enontekiö' 'Espoo' 'Eura' 'Eurajoki'
#  'Evijärvi' 'Finström' 'Forssa' 'Föglö' 'Geta' 'Haapajärvi' 'Haapavesi'
#  'Hailuoto' 'Halsua' 'Hamina' 'Hammarland' 'Hankasalmi' 'Hanko'
#  'Harjavalta' 'Hartola' 'Hattula' 'Hausjärvi' 'Heinola' 'Heinävesi'
#  'Helsinki' 'Hirvensalmi' 'Hollola' 'Honkajoki' 'Huittinen' 'Humppila'
#  'Hyrynsalmi' 'Hyvinkää' 'Hämeenkyrö' 'Hämeenlinna' 'Ii' 'Iisalmi' 'Iitti'
#  'Ikaalinen' 'Ilmajoki' 'Ilomantsi' 'Imatra' 'Inari' 'Inkoo' 'Isojoki'
#  'Isokyrö' 'Janakkala' 'Joensuu' 'Jokioinen' 'Jomala' 'Joroinen' 'Joutsa'
#  'Juuka' 'Juupajoki' 'Juva' 'Jyväskylä' 'Jämijärvi' 'Jämsä' 'Järvenpää'
#  'Kaarina' 'Kaavi' 'Kajaani' 'Kalajoki' 'Kangasala' 'Kangasniemi'
#  'Kankaanpää' 'Kannonkoski' 'Kannus' 'Karijoki' 'Karkkila' 'Karstula'
#  'Karvia' 'Kaskinen' 'Kauhajoki' 'Kauhava' 'Kauniainen' 'Kaustinen'
# ...

# %%
df[df['Väkiluku, 2017']>40000]
# Out:
#             Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 11          Espoo                   99.5          279044
# 33       Helsinki                  100.0          643272
# 40       Hyvinkää                   93.9           46739
# 42    Hämeenlinna                   87.7           67662
# 55        Joensuu                   89.1           76067
# 63      Jyväskylä                   94.7          140188
# 66      Järvenpää                   99.9           42572
# 101       Kokkola                   87.7           47723
# 107         Kotka                   98.2           53539
# 108       Kouvola                   86.0           84196
# 114        Kuopio                   85.7          118209
# 123         Lahti                   97.4          119573
# 129  Lappeenranta                   89.9           72909
# 141         Lohja                   82.2           46785
# 157       Mikkeli                   80.0           54261
# ...

# %%
df[df['Väkiluku, 2017']<10000]
# Out:
#              Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 1         Alajärvi                   60.7            9831
# 2        Alavieska                   52.6            2610
# 4         Asikkala                   64.4            8248
# 5           Askola                   53.2            4990
# 6             Aura                   69.9            3991
# 7           Brändö                    0.0             452
# 8           Eckerö                   41.8             948
# 9        Enonkoski                   39.9            1416
# 10       Enontekiö                   30.7            1893
# 13        Eurajoki                   62.9            9521
# 14        Evijärvi                   35.7            2499
# 15        Finström                   41.5            2580
# 17           Föglö                    0.0             532
# 18            Geta                    0.0             495
# 19      Haapajärvi                   69.5            7251
# ...

# %%
df[(df['Ruotsinkielisten osuus väestöstä, %, 2017'].isnull()) & (df['Ulkomaan kansalaisten osuus väestöstä, %, 2017'].isnull()) ]
# Out:
# Empty DataFrame
# ...
