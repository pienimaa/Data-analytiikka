# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import quandl
quandl.ApiConfig.api_key = 'xxxx'

# %%
disney=quandl.get("EOD/DIS")
disney.head()
# Out:
#              Open   High    Low  Close  Volume  Dividend  Split  Adj_Open  \
# Date
# 1962-01-02  37.25  38.50  37.25  37.25  2098.0       0.0    1.0  0.137931
# 1962-01-03  37.25  37.88  37.25  37.75  1998.0       0.0    1.0  0.137931
# 1962-01-04  37.75  37.88  37.50  37.75  2397.0       0.0    1.0  0.139782
# 1962-01-05  37.75  38.00  37.63  37.88  2397.0       0.0    1.0  0.139782
# 1962-01-08  37.88  38.38  37.00  37.75  3197.0       0.0    1.0  0.140264
#
#             Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Date
# 1962-01-02  0.142559  0.137931   0.137931   408858.24
# 1962-01-03  0.140264  0.137931   0.139782   389370.24
# 1962-01-04  0.140264  0.138857   0.139782   467127.36
# 1962-01-05  0.140708  0.139338   0.140264   467127.36
# 1962-01-08  0.142115  0.137005   0.139782   623031.36

# %%
popkemi=quandl.get('CITYPOP/CITY_KEMILAPFINLAND')
popkemi.head()
# Out:
#             Population
# Year
# 1980-12-31     26928.0
# 1990-12-31     25374.0
# 2000-12-31     23689.0
# 2010-12-31     22537.0
# 2014-12-31     27558.0

# %%
popkemi.plot()

# %%
pophelsinki=quandl.get('CITYPOP/CITY_HELSINKIUUSFINLAND')
pophelsinki.head()
# Out:
#             Population
# Year
# 1980-12-31    483036.0
# 1990-12-31    492400.0
# 2000-12-31    555474.0
# 2010-12-31    588549.0
# 2014-12-31   1214210.0

# %%
pophelsinki.plot()

# %%
popkuopio=quandl.get('CITYPOP/CITY_KUOPIOPSAFINLAND')
popkuopio.head()
# Out:
#             Population
# Year
# 1980-12-31     99687.0
# 1990-12-31    104675.0
# 2000-12-31    108890.0
# 2010-12-31    112336.0
# 2014-12-31     86034.0

# %%
popkuopio.plot()

# %%
pop_city=pd.concat([popkuopio, pophelsinki, popkemi], axis=1)

pop_city.columns=['Kuopio', 'Helsinki', 'Kemi']

pop_city.plot()

# %%
share_japan=quandl.get('WFE/SHARES_JAPANEXCHANGEGROUPINC')
share_japan.head()
# Out:
#                     Value
# Date
# 2017-01-31  417377.380877
# 2017-02-28  432116.340608
# 2017-03-31  470494.245996
# 2017-04-30  437602.446878
# 2017-05-31  481479.282311

# %%
share_japan.plot()

# %%
share_japan['2018':].plot()

# %%
bond_japan=quandl.get('WFE/BONDVAL_JAPANEXCHANGEGROUPINC')
bond_japan.head()
# Out:
#                 Value
# Date
# 2017-01-31  50.044368
# 2017-02-28  36.284089
# 2017-03-31  29.426219
# 2017-04-30  14.841195
# 2017-05-31  34.651261

# %%
bond_japan.plot()

# %%
disney=quandl.get("EOD/DIS")
disney.head()
# Out:
#              Open   High    Low  Close  Volume  Dividend  Split  Adj_Open  \
# Date
# 1962-01-02  37.25  38.50  37.25  37.25  2098.0       0.0    1.0  0.137931
# 1962-01-03  37.25  37.88  37.25  37.75  1998.0       0.0    1.0  0.137931
# 1962-01-04  37.75  37.88  37.50  37.75  2397.0       0.0    1.0  0.139782
# 1962-01-05  37.75  38.00  37.63  37.88  2397.0       0.0    1.0  0.139782
# 1962-01-08  37.88  38.38  37.00  37.75  3197.0       0.0    1.0  0.140264
#
#             Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Date
# 1962-01-02  0.142559  0.137931   0.137931   408858.24
# 1962-01-03  0.140264  0.137931   0.139782   389370.24
# 1962-01-04  0.140264  0.138857   0.139782   467127.36
# 1962-01-05  0.140708  0.139338   0.140264   467127.36
# 1962-01-08  0.142115  0.137005   0.139782   623031.36

# %%
disney.plot()

# %%
disney['Close'].plot()

#Liukuva keskiarvo:
disney['Close'].rolling(250).mean().plot()

# %%
#Kuukausikeskiarvot:
disney['Close']['2016':].resample('BM').mean().plot()

# %%
#Kuukauden viimeisen päivän hinnat:
disney['Close']['2016':].asfreq('BM').plot()
